# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
# %matplotlib inline

# %%
os.getcwd()
os.chdir()

# %%
img_list=["21.jpg","beautiful-landscape-view-from-here-dx-800x600.jpg","beautiful-scenery-pictures-ycxy8o2ii84zsgiv.jpg","download (4).jpg","lighthouse-168132_1280.jpg","mountains-100367_1920.jpg","wallpapersden.com_landscape-pixel-art_800x600.jpg"]
print(img_list)
# Out:
# ['21.jpg', 'beautiful-landscape-view-from-here-dx-800x600.jpg', 'beautiful-scenery-pictures-ycxy8o2ii84zsgiv.jpg', 'download (4).jpg', 'lighthouse-168132_1280.jpg', 'mountains-100367_1920.jpg', 'wallpapersden.com_landscape-pixel-art_800x600.jpg']

# %% [markdown]
# ### Checking Size of Images

# %%
s=[]
for img in img_list:
    im = cv2.imread(img,0)
    h,w = im.shape[:2]
    s.append(im.shape)
    print(im.shape)

s_h,s_w=0,0

for i,j in s:
    s_h,s_w=s_h+i,s_w+j
print("Avg of images h and w is:",s_h//len(s),s_w//len(s))
# Out:
# (1080, 1920)
# (600, 800)
# (900, 1600)
# (194, 259)
# (1280, 1024)
# (1274, 1920)
# (600, 800)
# Avg of images h and w is: 846 1189

# %% [markdown]
# ### Resizing the images to 600X800

# %%
# Out:
# 'C:\\Users\\ARPIT SHARMA\\Desktop\\lgm\\LGMVIP--DataScience-Image to Pencil Sketch with Python\\Resized Images'

# %%
for img in img_list:
    os.chdir("C:\\Users\\ARPIT SHARMA\\Desktop\\lgm\\LGMVIP--DataScience-Image to Pencil Sketch with Python")
    im=cv2.imread(img)
    #in resize we have width first and height second which is opposite when we print shape of a image
    r_img = cv2.resize(im,(1189 ,846))
    os.chdir("C:\\Users\\ARPIT SHARMA\\Desktop\\lgm\\LGMVIP--DataScience-Image to Pencil Sketch with Python\\Resized Images")
    output_path = img
    cv2.imwrite(output_path, r_img)
    
    h,w = r_img.shape[:2]
    print(r_img.shape)
# Out:
# (846, 1189, 3)
# (846, 1189, 3)
# (846, 1189, 3)
# (846, 1189, 3)
# (846, 1189, 3)
# (846, 1189, 3)
# (846, 1189, 3)

# %% [markdown]
# #### Note cwd is now Resized images from here on out

# %% [markdown]
# ### Applying Grayscale

# %%
num_images = len(img_list)
num_rows = 2
num_cols = (num_images + 1) // 2

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

for i,img in enumerate(img_list):
    #Converting img BGR TO GRAYSCALE
    img=cv2.imread(img)
    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    row = i // num_cols
    col = i % num_cols

    axes[row,col].imshow(gray_image,cmap="gray")
    axes[row,col].axis("off")

axes[1,3].axis("off")    
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Invert the grayscale image to create a negativ

# %%
num_images = len(img_list)
num_rows = 2
num_cols = (num_images + 1) // 2

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

for i,img in enumerate(img_list):
    #Converting img BGR TO GRAYSCALE
    img=cv2.imread(img)
    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    inverted_gray_image = 255 - gray_image
    row = i // num_cols
    col = i % num_cols

    axes[row,col].imshow(inverted_gray_image,cmap="gray")
    axes[row,col].axis("off")

axes[1,3].axis("off")    
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Apply Gaussian blur to the negative image

# %%
num_images = len(img_list)
num_rows = 2
num_cols = (num_images + 1) // 2

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

for i,img in enumerate(img_list):
    #Converting img BGR TO GRAYSCALE
    img=cv2.imread(img)
    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    inverted_gray_image = 255 - gray_image
    kernel_size = (21, 21)
    blurred_image = cv2.GaussianBlur(inverted_gray_image, kernel_size, sigmaX=0, sigmaY=0)
    row = i // num_cols
    col = i % num_cols

    axes[row,col].imshow(blurred_image,cmap="gray")
    axes[row,col].axis("off")

axes[1,3].axis("off")    
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Invert the blurred negative image

# %%
num_images = len(img_list)
num_rows = 2
num_cols = (num_images + 1) // 2

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

for i,img in enumerate(img_list):
    #Converting img BGR TO GRAYSCALE
    img=cv2.imread(img)
    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    inverted_gray_image = 255 - gray_image
    kernel_size = (21, 21)
    blurred_image = cv2.GaussianBlur(inverted_gray_image, kernel_size, sigmaX=0, sigmaY=0)
    inverted_blurred_image = 255 - blurred_image
    row = i // num_cols
    col = i % num_cols

    axes[row,col].imshow(inverted_blurred_image,cmap="gray")
    axes[row,col].axis("off")

axes[1,3].axis("off")    
    
plt.tight_layout()
plt.show()
